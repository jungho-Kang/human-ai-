# %%
# jupyter 내에서 pip install 해도 실행된다.
! pip install --upgrade matplotlib
# Out:
# Requirement already satisfied: matplotlib in d:\anaconda3\envs\ai\lib\site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda3\envs\ai\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda3\envs\ai\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda3\envs\ai\lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda3\envs\ai\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in d:\anaconda3\envs\ai\lib\site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda3\envs\ai\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in d:\anaconda3\envs\ai\lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in d:\anaconda3\envs\ai\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda3\envs\ai\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\anaconda3\envs\ai\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %% [markdown]
# ## numpy로 파일 읽어오기

# %%
data = np.genfromtxt('./data/ratings.dat', delimiter ='::', dtype=np.int64)
data
# Out:
# array([[        1,      1193,         5, 978300760],
#        [        1,       661,         3, 978302109],
#        [        1,       914,         3, 978301968],
#        ...,
#        [     6040,       562,         5, 956704746],
#        [     6040,      1096,         4, 956715648],
#        [     6040,      1097,         4, 956715569]], shape=(1000209, 4))

# %%
# 5행까지 확인
data[:6,:]
# Out:
# array([[        1,      1193,         5, 978300760],
#        [        1,       661,         3, 978302109],
#        [        1,       914,         3, 978301968],
#        [        1,      3408,         4, 978300275],
#        [        1,      2355,         5, 978824291],
#        [        1,      1197,         3, 978302268]])

# %%
data.shape
# Out:
# (1000209, 4)

# %%
names = pd.read_csv("./data/NationalNames.csv", header=0, names=['id', 'name', 'year', 'sex', 'births'])
names
# Out:
#               id       name  year sex  births
# 0              1       Mary  1880   F    7065
# 1              2       Anna  1880   F    2604
# 2              3       Emma  1880   F    2003
# 3              4  Elizabeth  1880   F    1939
# 4              5     Minnie  1880   F    1746
# ...          ...        ...   ...  ..     ...
# 1825428  1825429     Zykeem  2014   M       5
# 1825429  1825430     Zymeer  2014   M       5
# 1825430  1825431    Zymiere  2014   M       5
# 1825431  1825432      Zyran  2014   M       5
# 1825432  1825433      Zyrin  2014   M       5
#
# [1825433 rows x 5 columns]

# %%
names.count()
# Out:
# id        1825433
# name      1825433
# year      1825433
# sex       1825433
# births    1825433
# dtype: int64

# %%
# 처음부터 10개의 행 가져오기
names.head(10)
# Out:
#    id       name  year sex  births
# 0   1       Mary  1880   F    7065
# 1   2       Anna  1880   F    2604
# 2   3       Emma  1880   F    2003
# 3   4  Elizabeth  1880   F    1939
# 4   5     Minnie  1880   F    1746
# 5   6   Margaret  1880   F    1578
# 6   7        Ida  1880   F    1472
# 7   8      Alice  1880   F    1414
# 8   9     Bertha  1880   F    1320
# 9  10      Sarah  1880   F    1288

# %%
# 끝부터 10개의 행 가져오기
names.tail(10)
# Out:
#               id     name  year sex  births
# 1825423  1825424   Ziyang  2014   M       5
# 1825424  1825425  Zmarion  2014   M       5
# 1825425  1825426       Zo  2014   M       5
# 1825426  1825427    Zyeir  2014   M       5
# 1825427  1825428     Zyel  2014   M       5
# 1825428  1825429   Zykeem  2014   M       5
# 1825429  1825430   Zymeer  2014   M       5
# 1825430  1825431  Zymiere  2014   M       5
# 1825431  1825432    Zyran  2014   M       5
# 1825432  1825433    Zyrin  2014   M       5

# %% [markdown]
# ## 년도 별 남자와 여자의 총합 구하기

# %%
total_birth = names.pivot_table('births', index='year', columns='sex', aggfunc=sum)
# Out:
# C:\Users\human3_01\AppData\Local\Temp\ipykernel_11096\1465105271.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   total_birth = names.pivot_table('births', index='year', columns='sex', aggfunc=sum)

# %%
total_birth.head(10)
# Out:
# sex        F       M
# year
# 1880   90993  110491
# 1881   91954  100745
# 1882  107850  113688
# 1883  112321  104629
# 1884  129022  114445
# 1885  133055  107800
# 1886  144535  110784
# 1887  145982  101414
# 1888  178627  120853
# 1889  178366  110584

# %%
total_birth.plot(title='Total births by sex and year')
# Out:
# <Axes: title={'center': 'Total births by sex and year'}, xlabel='year'>

# %% [markdown]
# ## 요약
# ```
# 1. numpy
#    : 벡터, 행렬 연산에 편의성을 제공하는 라이브러리
# 2. pandas
#    : 데이터프레임 구조로 데이터 분석에 편의성을 제공하는 라이브러리
# 3. visualization(matplotlib, seaborn)
#    : 데이터 시각화를 위한 라이브러리
# ```
