# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score, auc, roc_curve
import joblib
import tensorflow as tf
from tensorflow.keras import layers, models

np.random.seed(42)
tf.random.set_seed(42)

# %%
# 가상 센서 데이터 생성
n_normal = 5000     # 정상데이터 샘플 수
n_anomaly = 500     # 이상 데이터 샘플 수
n_features = 4      # 센서 개수

# 정상 데이터 : 평균 0, 표준편차 1인 정규분포 내에서 값을 생성
normal_data = np.random.normal(loc=0.0, scale=1.0, size=(n_normal, n_features))

# 이상 데이터 : 평균을 크게 이동시키고, 분산을 키워서 비정상적인 패턴의 센서 데이터 생성
anomaly_data = np.random.normal(loc=3.0, scale=1.5, size=(n_anomaly, n_features))

# 정상과 이상 데이터를 위아래로 이어 붙임
X = np.vstack([normal_data, anomaly_data])

# 정상은 0, 이상은 1로 레이블 벡터를 만듬
y = np.hstack([np.zeros(n_normal), np.ones(n_anomaly)])

# %%
normal_data
# Out:
# array([[ 0.49671415, -0.1382643 ,  0.64768854,  1.52302986],
#        [-0.23415337, -0.23413696,  1.57921282,  0.76743473],
#        [-0.46947439,  0.54256004, -0.46341769, -0.46572975],
#        ...,
#        [ 2.03658236, -0.41274409,  1.23286679, -0.46866051],
#        [ 0.88883882,  0.90249166,  0.95259051,  0.38782734],
#        [ 1.37736658,  0.37835397,  1.71352973, -1.6199198 ]],
#       shape=(5000, 4))

# %%
# 학습/테스트 데이터 분리
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# autoencoder는 정상 데이터로만 학습하므로 정상 샘플만 필터링
X_train_normal = X_train[y_train == 0]

# %%
# 데이터 스케일링
scaler = StandardScaler()
scaler.fit(X_train_normal)

X_train_normal_scaled = scaler.transform(X_train_normal)
X_test_scaled = scaler.transform(X_test)

# %%
# AUTO ENCODER 모델 정의
input_dim = n_features   # 입력 차원은 센서 개수와 동일하게 설정
encoding_dim = 2         # 잠재공간(latent space) 2차원으로 설정해서 압축 진행

# 입력 레이어 정의 (입력 크기는 센서 개수와 동일하게)
input_layer = layers.Input(shape=(input_dim,), name="input")

# 인코더 부분 (입력을 작은 차원으로 압축하는 레이어)
# 8개의 뉴런으로 첫번째 레이어를 구성
encoded = layers.Dense(8, activation="relu", name="encoder_dense1")(input_layer)
# 2차원 잠재 표현으로 압축
encoded = layers.Dense(encoding_dim, activation="relu", name="encoder_dense2")(encoded)

# 디코더 부분 (압축된 표현을 다시 원래 차원으로 복원하는 레이어)
# 8개의 뉴런으로 복원을 하는 중간 레이어
decoded = layers.Dense(8, activation="relu", name="decoder_dense1")(encoded)
# 원래 입력 차원으로 복원 출력
decoded = layers.Dense(input_dim, activation="linear", name="decoder_output")(decoded)
# 입력부터 출력까지를 연결해주는 autoencoder 모델 구성
autoencoder = models.Model(inputs=input_layer, outputs=decoded, name="autoencoder_model1")

autoencoder.summary()
# Out:
# Model: "autoencoder_model1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)                   │ (None, 4)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ encoder_dense1 (Dense)               │ (None, 8)                   │              40 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ encoder_dense2 (Dense)               │ (None, 2)                   │              18 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ decoder_dense1 (Dense)               │ (None, 8)                   │              24 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ decoder_output (Dense)               │ (None, 4)                   │              36 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 118 (472.00 B)
#  Trainable params: 118 (472.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# autoencoder 컴파일 설정
autoencoder.compile(
    optimizer="adam",        # 학습 최적화 알고리즘 adam 사용
    loss="mse"               # 입력과 복원된 출력의 차이를 제곱 오차로 계산
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
# 모델 학습 (정상 데이터만 가지고 학습 진행)
history = autoencoder.fit(
    X_train_normal_scaled,     # 입력과 타겟이 동일한 정상 데이터를 사용
    X_train_normal_scaled,     # 입력을 그대로 복원하도록 학습
    epochs=70,                 # 70번 반복 학습
    batch_size=64,             # 미치배치 크기 64
    validation_split=0.2,        # 20% 검증
    verbose=1                  # 로그 출력
)
# Out:
# Epoch 1/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9569 - val_loss: 0.9402
# Epoch 2/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9125 - val_loss: 0.8903
# Epoch 3/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8532 - val_loss: 0.8127
# Epoch 4/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7720 - val_loss: 0.7293
# Epoch 5/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7015 - val_loss: 0.6749
# Epoch 6/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6587 - val_loss: 0.6374
# Epoch 7/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6268 - val_loss: 0.6093
# Epoch 8/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6003 - val_loss: 0.5873
# Epoch 9/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5790 - val_loss: 0.5715
# Epoch 10/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5633 - val_loss: 0.5608
# Epoch 11/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5518 - val_loss: 0.5531
# Epoch 12/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5431 - val_loss: 0.5471
# Epoch 13/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5363 - val_loss: 0.5421
# Epoch 14/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5306 - val_loss: 0.5380
# Epoch 15/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5256 - val_loss: 0.5343
# Epoch 16/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5213 - val_loss: 0.5310
# Epoch 17/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5173 - val_loss: 0.5279
# Epoch 18/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5136 - val_loss: 0.5251
# Epoch 19/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5103 - val_loss: 0.5225
# Epoch 20/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5072 - val_loss: 0.5202
# Epoch 21/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5044 - val_loss: 0.5178
# Epoch 22/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5018 - val_loss: 0.5157
# Epoch 23/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4994 - val_loss: 0.5136
# Epoch 24/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4972 - val_loss: 0.5117
# Epoch 25/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4951 - val_loss: 0.5098
# Epoch 26/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4931 - val_loss: 0.5079
# Epoch 27/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4912 - val_loss: 0.5062
# Epoch 28/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4894 - val_loss: 0.5045
# Epoch 29/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4878 - val_loss: 0.5030
# Epoch 30/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4862 - val_loss: 0.5017
# Epoch 31/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4847 - val_loss: 0.5003
# Epoch 32/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4832 - val_loss: 0.4991
# Epoch 33/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4818 - val_loss: 0.4979
# Epoch 34/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4805 - val_loss: 0.4967
# Epoch 35/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4794 - val_loss: 0.4956
# Epoch 36/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4782 - val_loss: 0.4945
# Epoch 37/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4772 - val_loss: 0.4935
# Epoch 38/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4762 - val_loss: 0.4928
# Epoch 39/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4750 - val_loss: 0.4921
# Epoch 40/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4741 - val_loss: 0.4914
# Epoch 41/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4733 - val_loss: 0.4911
# Epoch 42/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4725 - val_loss: 0.4906
# Epoch 43/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4716 - val_loss: 0.4905
# Epoch 44/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4709 - val_loss: 0.4903
# Epoch 45/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4702 - val_loss: 0.4900
# Epoch 46/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4696 - val_loss: 0.4898
# Epoch 47/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4690 - val_loss: 0.4890
# Epoch 48/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4684 - val_loss: 0.4886
# Epoch 49/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4680 - val_loss: 0.4883
# Epoch 50/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4676 - val_loss: 0.4879
# Epoch 51/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4672 - val_loss: 0.4877
# Epoch 52/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4668 - val_loss: 0.4875
# Epoch 53/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4665 - val_loss: 0.4875
# Epoch 54/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4663 - val_loss: 0.4872
# Epoch 55/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4660 - val_loss: 0.4876
# Epoch 56/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4659 - val_loss: 0.4868
# Epoch 57/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4657 - val_loss: 0.4873
# Epoch 58/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4656 - val_loss: 0.4869
# Epoch 59/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4653 - val_loss: 0.4868
# Epoch 60/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4652 - val_loss: 0.4868
# Epoch 61/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4650 - val_loss: 0.4863
# Epoch 62/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4651 - val_loss: 0.4861
# Epoch 63/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4648 - val_loss: 0.4867
# Epoch 64/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4647 - val_loss: 0.4864
# Epoch 65/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4646 - val_loss: 0.4864
# Epoch 66/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4645 - val_loss: 0.4863
# Epoch 67/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4645 - val_loss: 0.4862
# Epoch 68/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4644 - val_loss: 0.4862
# Epoch 69/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4643 - val_loss: 0.4862
# Epoch 70/70
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4643 - val_loss: 0.4861

# %%
# 학습 결과 시각화
plt.rcParams["font.family"] = "Malgun Gothic"
plt.rcParams["axes.unicode_minus"] = False

plt.figure(figsize=(8,4))
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Val Loss")
plt.title("autoencoder 학습 손실 곡선")
plt.xlabel("epoch")
plt.ylabel("MSE Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
# 테스트 데이터에서 재구성 오차 계산

# 테스트 데이터를 autoencoder에 통과시켜서 복원값을 얻어옴
X_test_pred = autoencoder.predict(X_test_scaled)

# 각 샘플에 대해서(입력 - 복원값)^2를 계산, 특징 차원방향으로 평균을 내서 재구성 오차를 구하는 공식
reconstruction_error = np.mean(np.square(X_test_scaled - X_test_pred), axis=1)
# Out:
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# 이상 탐지 임계값 설정(threshold)

# 정상 학습 데이터의 재구성 오차 분포를 기반으로 임계값 설정
X_train_pred = autoencoder.predict(X_train_normal_scaled)     # 학습용 정상 데이터에서 복원값 구함
train_reconstruction_error = np.mean(                         # 정상 학습 데이터의 재구성 오차 계산
    np.square(X_train_normal_scaled - X_train_pred), axis=1
)

threshold = np.percentile(train_reconstruction_error, 95)     # 임계값 설정
print("이상탐지 임계값(95%) : ", threshold)
# Out:
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step
# 이상탐지 임계값(95%) :  1.4041235617417784

# %%
# 결과 시각화
plt.figure(figsize=(8,4))
plt.hist(reconstruction_error[y_test == 0], bins=50, alpha=0.7, label="정상")     # 정상 샘플 오차
plt.hist(reconstruction_error[y_test == 1], bins=50, alpha=0.7, label="이상")     # 이상 샘플 오차
plt.axvline(threshold, color="red", linestyle="--", label="임계값")

plt.title("정상 vs 이상 재구성 오차 분포")
plt.xlabel("재구성 오차 MSE")
plt.ylabel("샘플 수")
plt.legend()
plt.grid(True)
plt.show()
